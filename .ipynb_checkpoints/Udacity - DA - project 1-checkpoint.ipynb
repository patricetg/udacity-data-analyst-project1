# %% [markdown]
# > **Tip**: Welcome to the Investigate a Dataset project! You will find tips in quoted sections like this to help organize your approach to your investigation. Before submitting your project, it will be a good idea to go back through your report and remove these sections to make the presentation of your work as tidy as possible. First things first, you might want to double-click this Markdown cell and change the title so that it reflects your dataset and investigation.
#
# # Project: TMDb Data Analysis
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# https://stackoverflow.com/questions/41927973/pandas-dataframe-pipe-separated-values-in-a-cell
#
# https://www.google.com/search?q=dealing+with+values+separted+by+pipe+in+pandas+dataframe&rlz=1C1XXVF_frTG984TG984&sxsrf=ALiCzsbFVhpfkWxinlCkh-7Q_-jcpjMvmg%3A1670590433715&ei=4S-TY72nK4PFgQbou72wDw&ved=0ahUKEwj9m_eqyuz7AhWDYsAKHehdD_YQ4dUDCA8&uact=5&oq=dealing+with+values+separted+by+pipe+in+pandas+dataframe&gs_lcp=...&sclient=gws-wiz-serp

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# > **Tip**: In this section of the report, provide a brief introduction to the dataset you've selected for analysis. At the end of this section, describe the questions that you plan on exploring over the course of the report. Try to build your report around the analysis of at least one dependent variable and three independent variables.
# >
# > If you haven't yet selected and downloaded your data, make sure you do that first before coming back here. If you're not sure what questions to ask right now, then make sure you familiarize yourself with the variables and the dataset context for ideas of what to explore.
#
#
# > TODO : delete this text later.
# This data set contains information
# about 10,000 movies collected from
# The Movie Database (TMDb),
# including user ratings and revenue.
# ● Certain columns, like ‘cast’
# and ‘genres’, contain multiple
# values separated by pipe (|)
# characters.
# ● There are some odd characters
# in the ‘cast’ column. Don’t worry
# about cleaning them. You can
# leave them as is.
# ● The final two columns ending
# with “_adj” show the budget and
# revenue of the associated movie
# in terms of 2010 dollars,
# accounting for inflation over
# time.
#
# -------------------
#
# We are planing to invest in the movies business, so our aim is to understand the sector in order to know what are the best investment options available to us.
# In this project, we will be analyzing data associated with The Movie Database (TMDb), including user ratings and revenue, which contains information about 10,000 movies. In particular, we will be interested in :
# 1. Which genre of movies are on trend, so that we define the direction of our investment ?
# 2. Between the genres of movies on trend, what is the correlation between them and revenue ?
# 3. What is the minimum amount of budget we should allocate to the choosen movie genre, in order to score in the highest movie revenues ?
# 4. Which are the companies that are best at the genre of movie we are targeting ?
# 5. Does having a website for the genre that is of interest to us help improve revenue ?

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline


from typing import List, Tuple

# %%
def unpipe_features(df:pd.DataFrame, features:List[str], separator:str="|")->pd.DataFrame:
    """
        Remove pipes (or any given separator) from features cells, and create new lines
            based on each item of the cell
    """
    for feature in features:
        print("********************"*5)
        print("Working on feature : {} ".format(feature))
        df = unpipe_feature(df=df, feature=feature, separator=separator)
        print("Work on feature {} ended".format(feature))
    return df

# %%
def unpipe_feature(df:pd.DataFrame, feature:str, separator:str="|")->pd.DataFrame:
    """
        Remove pipes (or any given separator) from a feature cell, and create new lines
            based on each item of the cell
    
        References : 
          - https://stackoverflow.com/questions/41927973/pandas-dataframe-pipe-separated-values-in-a-cell
          - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.itertuples.html#pandas.DataFrame.itertuples
          - https://docs.python.org/3/library/itertools.html
    """
    
    print("Shape of dataset before processing : {}".format(df.shape))
    print("........"*8)
    
    all_rows = [] #np.empty(shape=df.shape)
    
    # duplicate feature, and putting an underscore at the end of the duplicated column 
    target_col = "{}_".format(feature)
    df[target_col] = df[feature]
    
    for index,row in df.iterrows(): 
        print("Processing row index : {} ".format(index))
#         print(row)
#         print("..."*2)
#         print(row["popularity"])
#         print("..."*2)
#         print(index)
#         print("---"*8)

        # split the datas in list
        col_datas:list[str] = str(row[target_col]).split(separator)
            
        rows = [ list(row[df.columns[:-1]]) + [data] for data in col_datas]
        all_rows += rows
        print("-------"*6)
        
    print("Processed all rows in dataset")    
    df_2 = pd.DataFrame(data=all_rows, columns=df.columns)
    df_2[feature]=df_2[target_col]
    
    df_2.drop([target_col],axis=1,inplace=True)
    print("Generated new dataframe")
    print("Shape of new dataset : {}".format(df_2.shape))
    print("........"*8)
    
    return df_2

# %%
def unpipe_feature_nextgen(df:pd.DataFrame, feature:str, separator:str="|")->pd.DataFrame:
    """
        Remove pipes (or any given separator) from a feature cell, and create new lines
            based on each item of the cell
    
        References : 
          - https://stackoverflow.com/questions/41927973/pandas-dataframe-pipe-separated-values-in-a-cell
          
    """
    
    all_rows = np.array([])  #np.empty(shape=df.shape)
    
    # duplicate feature, and putting an underscore at the end of the duplicated column 
    target_col = "{}_".format(feature)
    df[target_col] = df[feature]
    
    for index,row in df.iterrows():  # df.iloc[:2,:].iterrows(): #
#         print(row)
#         print("..."*2)
#         print(row["popularity"])
#         print("..."*2)
#         print(index)
#         print("---"*8)

        # split the datas in list
        col_datas:list[str] = str(row[target_col]).split(separator)
            
        rows = np.array( [ list(row[df.columns[:-1]]) + [data] for data in col_datas] )
        #all_rows[index,:] = rows
        all_rows = np.append(all_rows,rows)
        
    df_2 = pd.DataFrame(data=all_rows, columns=df.columns)
    df_2[feature]=df_2[target_col]
    
    df_2.drop([target_col],axis=1,inplace=True)
    
    return df_2

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
# > **Tip**: In this section of the report, you will load in the data, check for cleanliness, and then trim and clean your dataset for analysis. Make sure that you document your steps carefully and justify your cleaning decisions.
#
# ### General Properties

# %%
# Load your data and print out a few lines. Perform operations to inspect data
#   types and look for instances of missing or possibly errant data.

# %%
df = pd.read_csv("tmdb-movies.csv")
df.head(2).T
# Out:
#                                                                       0  \
# id                                                               135397
# imdb_id                                                       tt0369610
# popularity                                                    32.985763
# budget                                                        150000000
# revenue                                                      1513528810
# original_title                                           Jurassic World
# cast                  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# homepage                                  http://www.jurassicworld.com/
# director                                                Colin Trevorrow
# tagline                                               The park is open.
# keywords              monster|dna|tyrannosaurus rex|velociraptor|island
# overview              Twenty-two years after the events of Jurassic ...
# runtime                                                             124
# genres                        Action|Adventure|Science Fiction|Thriller
# production_companies  Universal Studios|Amblin Entertainment|Legenda...
# release_date                                                     6/9/15
# vote_count                                                         5562
# vote_average                                                        6.5
# release_year                                                       2015
# budget_adj                                             137999939.280026
# revenue_adj                                             1392445892.5238
#
#                                                                       1
# id                                                                76341
# imdb_id                                                       tt1392190
# popularity                                                    28.419936
# budget                                                        150000000
# revenue                                                       378436354
# original_title                                       Mad Max: Fury Road
# cast                  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# homepage                                    http://www.madmaxmovie.com/
# director                                                  George Miller
# tagline                                              What a Lovely Day.
# keywords               future|chase|post-apocalyptic|dystopia|australia
# overview              An apocalyptic story set in the furthest reach...
# runtime                                                             120
# genres                        Action|Adventure|Science Fiction|Thriller
# production_companies  Village Roadshow Pictures|Kennedy Miller Produ...
# release_date                                                    5/13/15
# vote_count                                                         6185
# vote_average                                                        7.1
# release_year                                                       2015
# budget_adj                                             137999939.280026
# revenue_adj                                            348161292.489031

# %% [markdown]
# The features name are self-explanotory, but we will still explain them in order to avoid/clear any confusion that may exists :
# * id : movie id, in TMDb database
# * imdb_id : movie id, in IMDd database
# * popularity : movie popularity score, in IMDb database
# * budget : budget used to make the movie
# * revenue : revenue generated by the movie
# * original_title : movie original title
# * cast : cast team of the movie
# * homepage : movie website
# * director : movie casting team director
# * tagline : the movie tagline
# * keywords : movie keywords/hashtags
# * overview : movie overview
# * runtime : movie runtime, in minutes
# * genres : movie genres
# * production_companies : companies which producted the movie
# * release_date : movie release date
# * vote_count : number of person which give a rating for the movie
# * vote_average : average rating for the movie
# * release_year : movie release year
# * budget_adj : budget of the movie in terms of 2010 dollars, accounting for inflation over time
# * revenue_adj : revenue of the movie in terms of 2010 dollars, accounting for inflation over time

# %% [markdown]
# ### Getting an overview of the data

# %%
# Checking the number of samples and features in the dataset
df.shape
# Out:
# (10866, 21)

# %%
# Checking the data structure
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
#  15  release_date          10866 non-null  object
#  16  vote_count            10866 non-null  int64
#  17  vote_average          10866 non-null  float64
#  18  release_year          10866 non-null  int64
#  19  budget_adj            10866 non-null  float64
#  20  revenue_adj           10866 non-null  float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 1.7+ MB

# %%
# Number of N/A values per feature
df.isna().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
# Number of NULL values per feature
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %% [markdown]
# **Data Overview conclustion** :
# * Over a total of 10866 samples, homepage has 7930 null value. We will assume for our work that null value here is due to not having a website.
# * The other samples which have null values will be dropped.

# %%
#df.hist(figsize=(15,15));

# %%
#df[ df["homepage"].isnull() ].hist(figsize=(15,15));

# %% [markdown]
# ### Data Cleaning

# %%
# After discussing the structure of the data and any problems that need to be
#   cleaned, perform those cleaning steps in the second part of this section.

# %% [markdown]
# Dropping the null values, while having `homepage` as feature let us with a dataset of shape (1992, 21), which is too little for our analysis.
# So, we will first create a new feature, `no_website`, which will tell weither a movie has a homepage or not (assuming that not having a homepage in the dataset is due to not having one hosted, and not due to not having find it).

# %%
# Creating a new feature, has_website, to tell weither the movie has a website or not
df["no_website"] = df["homepage"].isnull() | df["homepage"].isna() 
df.head(3).T
# Out:
#                                                                       0  \
# id                                                               135397
# imdb_id                                                       tt0369610
# popularity                                                    32.985763
# budget                                                        150000000
# revenue                                                      1513528810
# original_title                                           Jurassic World
# cast                  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# homepage                                  http://www.jurassicworld.com/
# director                                                Colin Trevorrow
# tagline                                               The park is open.
# keywords              monster|dna|tyrannosaurus rex|velociraptor|island
# overview              Twenty-two years after the events of Jurassic ...
# runtime                                                             124
# genres                        Action|Adventure|Science Fiction|Thriller
# production_companies  Universal Studios|Amblin Entertainment|Legenda...
# release_date                                                     6/9/15
# vote_count                                                         5562
# vote_average                                                        6.5
# release_year                                                       2015
# budget_adj                                             137999939.280026
# revenue_adj                                             1392445892.5238
# no_website                                                        False
#
#                                                                       1  \
# id                                                                76341
# imdb_id                                                       tt1392190
# popularity                                                    28.419936
# budget                                                        150000000
# revenue                                                       378436354
# original_title                                       Mad Max: Fury Road
# cast                  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# homepage                                    http://www.madmaxmovie.com/
# director                                                  George Miller
# tagline                                              What a Lovely Day.
# keywords               future|chase|post-apocalyptic|dystopia|australia
# overview              An apocalyptic story set in the furthest reach...
# runtime                                                             120
# genres                        Action|Adventure|Science Fiction|Thriller
# production_companies  Village Roadshow Pictures|Kennedy Miller Produ...
# release_date                                                    5/13/15
# vote_count                                                         6185
# vote_average                                                        7.1
# release_year                                                       2015
# budget_adj                                             137999939.280026
# revenue_adj                                            348161292.489031
# no_website                                                        False
#
#                                                                       2
# id                                                               262500
# imdb_id                                                       tt2908446
# popularity                                                    13.112507
# budget                                                        110000000
# revenue                                                       295238201
# original_title                                                Insurgent
# cast                  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# homepage                 http://www.thedivergentseries.movie/#insurgent
# director                                               Robert Schwentke
# tagline                                      One Choice Can Destroy You
# keywords              based on novel|revolution|dystopia|sequel|dyst...
# overview              Beatrice Prior must confront her inner demons ...
# runtime                                                             119
# genres                               Adventure|Science Fiction|Thriller
# production_companies  Summit Entertainment|Mandeville Films|Red Wago...
# release_date                                                    3/18/15
# vote_count                                                         2480
# vote_average                                                        6.3
# release_year                                                       2015
# budget_adj                                             101199955.472019
# revenue_adj                                            271619025.407628
# no_website                                                        False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
#  15  release_date          10866 non-null  object
#  16  vote_count            10866 non-null  int64
#  17  vote_average          10866 non-null  float64
#  18  release_year          10866 non-null  int64
#  19  budget_adj            10866 non-null  float64
#  20  revenue_adj           10866 non-null  float64
#  21  no_website            10866 non-null  bool
# dtypes: bool(1), float64(4), int64(6), object(11)
# memory usage: 1.8+ MB

# %%
df["no_website"].unique()
# Out:
# array([False,  True])

# %%
# Checking the current shape of the dataframe
df.shape
# Out:
# (10866, 22)

# %%
# Droping homepage feature
df.drop(["homepage"],axis=1,inplace=True)

# Checking that homepage was removed
df.shape
# Out:
# (10866, 21)

# %%
# Drop null value
df.dropna(inplace=True)

# Looking at the new shape of our dataset
df.shape
# Out:
# (7031, 21)

# %%
# Making sure there is no more null or N/A value

# %%
df.isna().sum()
# Out:
# id                      0
# imdb_id                 0
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# cast                    0
# director                0
# tagline                 0
# keywords                0
# overview                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# vote_average            0
# release_year            0
# budget_adj              0
# revenue_adj             0
# no_website              0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# id                      0
# imdb_id                 0
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# cast                    0
# director                0
# tagline                 0
# keywords                0
# overview                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# vote_average            0
# release_year            0
# budget_adj              0
# revenue_adj             0
# no_website              0
# dtype: int64

# %%
df.head(3).T
# Out:
#                                                                       0  \
# id                                                               135397
# imdb_id                                                       tt0369610
# popularity                                                    32.985763
# budget                                                        150000000
# revenue                                                      1513528810
# original_title                                           Jurassic World
# cast                  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# director                                                Colin Trevorrow
# tagline                                               The park is open.
# keywords              monster|dna|tyrannosaurus rex|velociraptor|island
# overview              Twenty-two years after the events of Jurassic ...
# runtime                                                             124
# genres                        Action|Adventure|Science Fiction|Thriller
# production_companies  Universal Studios|Amblin Entertainment|Legenda...
# release_date                                                     6/9/15
# vote_count                                                         5562
# vote_average                                                        6.5
# release_year                                                       2015
# budget_adj                                             137999939.280026
# revenue_adj                                             1392445892.5238
# no_website                                                        False
#
#                                                                       1  \
# id                                                                76341
# imdb_id                                                       tt1392190
# popularity                                                    28.419936
# budget                                                        150000000
# revenue                                                       378436354
# original_title                                       Mad Max: Fury Road
# cast                  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# director                                                  George Miller
# tagline                                              What a Lovely Day.
# keywords               future|chase|post-apocalyptic|dystopia|australia
# overview              An apocalyptic story set in the furthest reach...
# runtime                                                             120
# genres                        Action|Adventure|Science Fiction|Thriller
# production_companies  Village Roadshow Pictures|Kennedy Miller Produ...
# release_date                                                    5/13/15
# vote_count                                                         6185
# vote_average                                                        7.1
# release_year                                                       2015
# budget_adj                                             137999939.280026
# revenue_adj                                            348161292.489031
# no_website                                                        False
#
#                                                                       2
# id                                                               262500
# imdb_id                                                       tt2908446
# popularity                                                    13.112507
# budget                                                        110000000
# revenue                                                       295238201
# original_title                                                Insurgent
# cast                  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# director                                               Robert Schwentke
# tagline                                      One Choice Can Destroy You
# keywords              based on novel|revolution|dystopia|sequel|dyst...
# overview              Beatrice Prior must confront her inner demons ...
# runtime                                                             119
# genres                               Adventure|Science Fiction|Thriller
# production_companies  Summit Entertainment|Mandeville Films|Red Wago...
# release_date                                                    3/18/15
# vote_count                                                         2480
# vote_average                                                        6.3
# release_year                                                       2015
# budget_adj                                             101199955.472019
# revenue_adj                                            271619025.407628
# no_website                                                        False

# %% [markdown]
# In our current dataset, we have release_date and release_year. We will focus on the year, and drop the date.

# %%
df.drop(["release_date"],axis=1,inplace=True)
df.head(3).T
# Out:
#                                                                       0  \
# id                                                               135397
# imdb_id                                                       tt0369610
# popularity                                                    32.985763
# budget                                                        150000000
# revenue                                                      1513528810
# original_title                                           Jurassic World
# cast                  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# director                                                Colin Trevorrow
# tagline                                               The park is open.
# keywords              monster|dna|tyrannosaurus rex|velociraptor|island
# overview              Twenty-two years after the events of Jurassic ...
# runtime                                                             124
# genres                        Action|Adventure|Science Fiction|Thriller
# production_companies  Universal Studios|Amblin Entertainment|Legenda...
# vote_count                                                         5562
# vote_average                                                        6.5
# release_year                                                       2015
# budget_adj                                             137999939.280026
# revenue_adj                                             1392445892.5238
# no_website                                                        False
#
#                                                                       1  \
# id                                                                76341
# imdb_id                                                       tt1392190
# popularity                                                    28.419936
# budget                                                        150000000
# revenue                                                       378436354
# original_title                                       Mad Max: Fury Road
# cast                  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# director                                                  George Miller
# tagline                                              What a Lovely Day.
# keywords               future|chase|post-apocalyptic|dystopia|australia
# overview              An apocalyptic story set in the furthest reach...
# runtime                                                             120
# genres                        Action|Adventure|Science Fiction|Thriller
# production_companies  Village Roadshow Pictures|Kennedy Miller Produ...
# vote_count                                                         6185
# vote_average                                                        7.1
# release_year                                                       2015
# budget_adj                                             137999939.280026
# revenue_adj                                            348161292.489031
# no_website                                                        False
#
#                                                                       2
# id                                                               262500
# imdb_id                                                       tt2908446
# popularity                                                    13.112507
# budget                                                        110000000
# revenue                                                       295238201
# original_title                                                Insurgent
# cast                  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# director                                               Robert Schwentke
# tagline                                      One Choice Can Destroy You
# keywords              based on novel|revolution|dystopia|sequel|dyst...
# overview              Beatrice Prior must confront her inner demons ...
# runtime                                                             119
# genres                               Adventure|Science Fiction|Thriller
# production_companies  Summit Entertainment|Mandeville Films|Red Wago...
# vote_count                                                         2480
# vote_average                                                        6.3
# release_year                                                       2015
# budget_adj                                             101199955.472019
# revenue_adj                                            271619025.407628
# no_website                                                        False

# %%
# %%timeit
# xx = unpipe_feature(df,"genres")
# xx.head(20).T

# %%
#%%timeit
"""
# Removing the pipes in our dataset features
to_unpipes = ["cast","keywords","genres","production_companies"]

df = unpipe_features(df=df, features=to_unpipes, separator="|")
df.head(20).T"""

# This code was commented because it is taking forever to run. The pipes will be removed from the cells
#   when required.
# Out:
# '\n# Removing the pipes in our dataset features\nto_unpipes = ["cast","keywords","genres","production_companies"]\n\ndf = unpipe_features(df=df, features=to_unpipes, separator="|")\ndf.head(20).T'

# %% [markdown]
# The dataset is now ready to be used in the Exploratory Data Analysis

# %%
# Saving the dataset for later use
#df.to_csv("unpiped_tmdb.csv")

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
#
# > **Tip**: Now that you've trimmed and cleaned your data, you're ready to move on to exploration. Compute statistics and create visualizations with the goal of addressing the research questions that you posed in the Introduction section. It is recommended that you be systematic with your approach. Look at one variable at a time, and then follow it up by looking at relationships between variables.
#
#
#
# ### Which genres of movies are on trend ?
# We will explore the relationship between movie genres and production years. We will try to understand how movies production evolved over the years, and which genres of movies are most producted in recent years.

# %%
# Use this, and more code cells, to explore your data. Don't forget to add
#   Markdown cells to document your observations and findings.

# %%
# List of movie genres
df["genres"].unique()
# Out:
# array(['Action|Adventure|Science Fiction|Thriller',
#        'Adventure|Science Fiction|Thriller',
#        'Action|Adventure|Science Fiction|Fantasy', ...,
#        'Adventure|Comedy|Fantasy|Science Fiction',
#        'Adventure|Drama|Action|Family|Foreign',
#        'Comedy|Family|Mystery|Romance'], dtype=object)

# %%
# Current shape of dataset
df.shape
# Out:
# (7031, 20)

# %% [markdown]
# We will first remove the pipes from the `genres` cells, in order to have the dataset in the right format for our analysis.

# %%
to_unpipes =["genres"]  #["cast","keywords","genres","production_companies"]

df = unpipe_features(df=df, features=to_unpipes, separator="|")  # df.iloc[:10,:]
df.head(3).T
# Out:
# Shape of dataset before processing : (7031, 20)
# ................................................................
# Processing row index : 0
# ------------------------------------------
# Processing row index : 1
# ------------------------------------------
# Processing row index : 2
# ------------------------------------------
# Processing row index : 3
# ------------------------------------------
# Processing row index : 4
# ------------------------------------------
# Processing row index : 5
# ------------------------------------------
# Processing row index : 6
# ------------------------------------------
# Processing row index : 7
# ------------------------------------------
# Processing row index : 8
# ------------------------------------------
# Processing row index : 9
# ------------------------------------------
# Processing row index : 10
# ------------------------------------------
# Processing row index : 11
# ------------------------------------------
# Processing row index : 12
# ------------------------------------------
# Processing row index : 13
# ------------------------------------------
# Processing row index : 14
# ------------------------------------------
# Processing row index : 15
# ------------------------------------------
# Processing row index : 16
# ------------------------------------------
# Processing row index : 17
# ------------------------------------------
# Processing row index : 18
# ------------------------------------------
# Processing row index : 19
# ------------------------------------------
# Processing row index : 20
# ------------------------------------------
# Processing row index : 21
# ------------------------------------------
# Processing row index : 22
# ------------------------------------------
# Processing row index : 23
# ------------------------------------------
# Processing row index : 24
# ------------------------------------------
# Processing row index : 25
# ------------------------------------------
# Processing row index : 26
# ------------------------------------------
# Processing row index : 27
# ------------------------------------------
# Processing row index : 28
# ------------------------------------------
# Processing row index : 29
# ------------------------------------------
# Processing row index : 30
# ------------------------------------------
# Processing row index : 31
# ------------------------------------------
# Processing row index : 32
# ------------------------------------------
# Processing row index : 33
# ------------------------------------------
# Processing row index : 34
# ------------------------------------------
# Processing row index : 35
# ------------------------------------------
# Processing row index : 36
# ------------------------------------------
# Processing row index : 37
# ------------------------------------------
# Processing row index : 38
# ------------------------------------------
# Processing row index : 39
# ------------------------------------------
# Processing row index : 40
# ------------------------------------------
# Processing row index : 41
# ------------------------------------------
# Processing row index : 43
# ------------------------------------------
# Processing row index : 44
# ------------------------------------------
# Processing row index : 45
# ------------------------------------------
# Processing row index : 46
# ------------------------------------------
# Processing row index : 47
# ------------------------------------------
# Processing row index : 48
# ------------------------------------------
# Processing row index : 49
# ------------------------------------------
# Processing row index : 50
# ------------------------------------------
# Processing row index : 51
# ------------------------------------------
# Processing row index : 52
# ------------------------------------------
# Processing row index : 54
# ------------------------------------------
# Processing row index : 55
# ------------------------------------------
# Processing row index : 56
# ------------------------------------------
# Processing row index : 57
# ------------------------------------------
# Processing row index : 58
# ------------------------------------------
# Processing row index : 59
# ------------------------------------------
# Processing row index : 60
# ------------------------------------------
# Processing row index : 61
# ------------------------------------------
# Processing row index : 62
# ------------------------------------------
# Processing row index : 63
# ------------------------------------------
# Processing row index : 64
# ------------------------------------------
# Processing row index : 65
# ------------------------------------------
# Processing row index : 66
# ------------------------------------------
# Processing row index : 67
# ------------------------------------------
# Processing row index : 68
# ------------------------------------------
# Processing row index : 69
# ------------------------------------------
# Processing row index : 70
# ------------------------------------------
# Processing row index : 71
# ------------------------------------------
# Processing row index : 73
# ------------------------------------------
# Processing row index : 75
# ------------------------------------------
# Processing row index : 76
# ------------------------------------------
# Processing row index : 77
# ------------------------------------------
# Processing row index : 78
# ------------------------------------------
# Processing row index : 79
# ------------------------------------------
# Processing row index : 80
# ------------------------------------------
# Processing row index : 81
# ------------------------------------------
# Processing row index : 82
# ------------------------------------------
# Processing row index : 83
# ------------------------------------------
# Processing row index : 84
# ------------------------------------------
# Processing row index : 85
# ------------------------------------------
# Processing row index : 86
# ------------------------------------------
# Processing row index : 87
# ------------------------------------------
# Processing row index : 88
# ------------------------------------------
# Processing row index : 89
# ------------------------------------------
# Processing row index : 90
# ------------------------------------------
# Processing row index : 91
# ------------------------------------------
# Processing row index : 93
# ------------------------------------------
# Processing row index : 94
# ------------------------------------------
# Processing row index : 95
# ------------------------------------------
# Processing row index : 96
# ------------------------------------------
# Processing row index : 97
# ------------------------------------------
# Processing row index : 98
# ------------------------------------------
# Processing row index : 99
# ------------------------------------------
# Processing row index : 101
# ------------------------------------------
# Processing row index : 102
# ------------------------------------------
# Processing row index : 104
# ------------------------------------------
# Processing row index : 105
# ------------------------------------------
# Processing row index : 106
# ------------------------------------------
# Processing row index : 107
# ------------------------------------------
# Processing row index : 108
# ------------------------------------------
# Processing row index : 109
# ------------------------------------------
# Processing row index : 110
# ------------------------------------------
# Processing row index : 111
# ------------------------------------------
# Processing row index : 112
# ------------------------------------------
# Processing row index : 113
# ------------------------------------------
# Processing row index : 114
# ------------------------------------------
# Processing row index : 115
# ------------------------------------------
# Processing row index : 116
# ------------------------------------------
# Processing row index : 117
# ------------------------------------------
# Processing row index : 118
# ------------------------------------------
# Processing row index : 119
# ------------------------------------------
# Processing row index : 120
# ------------------------------------------
# Processing row index : 121
# ------------------------------------------
# Processing row index : 122
# ------------------------------------------
# Processing row index : 123
# ------------------------------------------
# Processing row index : 124
# ------------------------------------------
# Processing row index : 125
# ------------------------------------------
# Processing row index : 126
# ------------------------------------------
# Processing row index : 127
# ------------------------------------------
# Processing row index : 128
# ------------------------------------------
# Processing row index : 129
# ------------------------------------------
# Processing row index : 131
# ------------------------------------------
# Processing row index : 132
# ------------------------------------------
# Processing row index : 135
# ------------------------------------------
# Processing row index : 136
# ------------------------------------------
# Processing row index : 137
# ------------------------------------------
# Processing row index : 138
# ------------------------------------------
# Processing row index : 139
# ------------------------------------------
# Processing row index : 141
# ------------------------------------------
# Processing row index : 142
# ------------------------------------------
# Processing row index : 143
# ------------------------------------------
# Processing row index : 145
# ------------------------------------------
# Processing row index : 146
# ------------------------------------------
# Processing row index : 147
# ------------------------------------------
# Processing row index : 148
# ------------------------------------------
# Processing row index : 150
# ------------------------------------------
# Processing row index : 151
# ------------------------------------------
# Processing row index : 152
# ------------------------------------------
# Processing row index : 157
# ------------------------------------------
# Processing row index : 158
# ------------------------------------------
# Processing row index : 159
# ------------------------------------------
# Processing row index : 162
# ------------------------------------------
# Processing row index : 163
# ------------------------------------------
# Processing row index : 166
# ------------------------------------------
# Processing row index : 167
# ------------------------------------------
# Processing row index : 168
# ------------------------------------------
# Processing row index : 170
# ------------------------------------------
# Processing row index : 171
# ------------------------------------------
# Processing row index : 172
# ------------------------------------------
# Processing row index : 173
# ------------------------------------------
# Processing row index : 174
# ------------------------------------------
# Processing row index : 175
# ------------------------------------------
# Processing row index : 176
# ------------------------------------------
# Processing row index : 181
# ------------------------------------------
# Processing row index : 183
# ------------------------------------------
# Processing row index : 184
# ------------------------------------------
# Processing row index : 185
# ------------------------------------------
# Processing row index : 186
# ------------------------------------------
# Processing row index : 187
# ------------------------------------------
# Processing row index : 188
# ------------------------------------------
# Processing row index : 191
# ------------------------------------------
# Processing row index : 193
# ------------------------------------------
# Processing row index : 195
# ------------------------------------------
# Processing row index : 197
# ------------------------------------------
# Processing row index : 198
# ------------------------------------------
# Processing row index : 199
# ------------------------------------------
# Processing row index : 200
# ------------------------------------------
# Processing row index : 201
# ------------------------------------------
# Processing row index : 204
# ------------------------------------------
# Processing row index : 205
# ------------------------------------------
# Processing row index : 206
# ------------------------------------------
# Processing row index : 207
# ------------------------------------------
# Processing row index : 208
# ------------------------------------------
# Processing row index : 209
# ------------------------------------------
# Processing row index : 210
# ------------------------------------------
# Processing row index : 211
# ------------------------------------------
# Processing row index : 212
# ------------------------------------------
# Processing row index : 214
# ------------------------------------------
# Processing row index : 215
# ------------------------------------------
# Processing row index : 221
# ------------------------------------------
# Processing row index : 223
# ------------------------------------------
# Processing row index : 224
# ------------------------------------------
# Processing row index : 225
# ------------------------------------------
# Processing row index : 226
# ------------------------------------------
# Processing row index : 227
# ------------------------------------------
# Processing row index : 229
# ------------------------------------------
# Processing row index : 230
# ------------------------------------------
# Processing row index : 233
# ------------------------------------------
# Processing row index : 234
# ------------------------------------------
# Processing row index : 235
# ------------------------------------------
# Processing row index : 237
# ------------------------------------------
# Processing row index : 238
# ------------------------------------------
# Processing row index : 239
# ------------------------------------------
# Processing row index : 241
# ------------------------------------------
# Processing row index : 242
# ------------------------------------------
# Processing row index : 243
# ------------------------------------------
# Processing row index : 245
# ------------------------------------------
# Processing row index : 247
# ------------------------------------------
# Processing row index : 248
# ------------------------------------------
# Processing row index : 249
# ------------------------------------------
# Processing row index : 251
# ------------------------------------------
# Processing row index : 255
# ------------------------------------------
# Processing row index : 256
# ------------------------------------------
# Processing row index : 260
# ------------------------------------------
# Processing row index : 261
# ------------------------------------------
# Processing row index : 262
# ------------------------------------------
# Processing row index : 263
# ------------------------------------------
# Processing row index : 265
# ------------------------------------------
# Processing row index : 267
# ------------------------------------------
# Processing row index : 269
# ------------------------------------------
# Processing row index : 270
# ------------------------------------------
# Processing row index : 272
# ------------------------------------------
# Processing row index : 273
# ------------------------------------------
# Processing row index : 280
# ------------------------------------------
# Processing row index : 285
# ------------------------------------------
# Processing row index : 287
# ------------------------------------------
# Processing row index : 288
# ------------------------------------------
# Processing row index : 289
# ------------------------------------------
# Processing row index : 290
# ------------------------------------------
# Processing row index : 291
# ------------------------------------------
# Processing row index : 292
# ------------------------------------------
# Processing row index : 301
# ------------------------------------------
# Processing row index : 302
# ------------------------------------------
# Processing row index : 304
# ------------------------------------------
# Processing row index : 308
# ------------------------------------------
# Processing row index : 310
# ------------------------------------------
# Processing row index : 312
# ------------------------------------------
# Processing row index : 313
# ------------------------------------------
# Processing row index : 316
# ------------------------------------------
# Processing row index : 318
# ------------------------------------------
# Processing row index : 321
# ------------------------------------------
# Processing row index : 323
# ------------------------------------------
# Processing row index : 331
# ------------------------------------------
# Processing row index : 332
# ------------------------------------------
# Processing row index : 333
# ------------------------------------------
# Processing row index : 334
# ------------------------------------------
# Processing row index : 336
# ------------------------------------------
# Processing row index : 337
# ------------------------------------------
# Processing row index : 338
# ------------------------------------------
# Processing row index : 340
# ------------------------------------------
# Processing row index : 342
# ------------------------------------------
# Processing row index : 346
# ------------------------------------------
# Processing row index : 348
# ------------------------------------------
# Processing row index : 350
# ------------------------------------------
# Processing row index : 352
# ------------------------------------------
# Processing row index : 353
# ------------------------------------------
# Processing row index : 354
# ------------------------------------------
# Processing row index : 355
# ------------------------------------------
# Processing row index : 356
# ------------------------------------------
# Processing row index : 359
# ------------------------------------------
# Processing row index : 360
# ------------------------------------------
# Processing row index : 362
# ------------------------------------------
# Processing row index : 365
# ------------------------------------------
# Processing row index : 366
# ------------------------------------------
# Processing row index : 367
# ------------------------------------------
# Processing row index : 372
# ------------------------------------------
# Processing row index : 373
# ------------------------------------------
# Processing row index : 376
# ------------------------------------------
# Processing row index : 378
# ------------------------------------------
# Processing row index : 379
# ------------------------------------------
# Processing row index : 380
# ------------------------------------------
# Processing row index : 381
# ------------------------------------------
# Processing row index : 383
# ------------------------------------------
# Processing row index : 387
# ------------------------------------------
# Processing row index : 396
# ------------------------------------------
# Processing row index : 397
# ------------------------------------------
# Processing row index : 399
# ------------------------------------------
# Processing row index : 405
# ------------------------------------------
# Processing row index : 406
# ------------------------------------------
# Processing row index : 407
# ------------------------------------------
# Processing row index : 411
# ------------------------------------------
# Processing row index : 412
# ------------------------------------------
# Processing row index : 418
# ------------------------------------------
# Processing row index : 420
# ------------------------------------------
# Processing row index : 421
# ------------------------------------------
# Processing row index : 423
# ------------------------------------------
# Processing row index : 426
# ------------------------------------------
# Processing row index : 427
# ------------------------------------------
# Processing row index : 428
# ------------------------------------------
# Processing row index : 432
# ------------------------------------------
# Processing row index : 436
# ------------------------------------------
# Processing row index : 446
# ------------------------------------------
# Processing row index : 447
# ------------------------------------------
# Processing row index : 448
# ------------------------------------------
# Processing row index : 449
# ------------------------------------------
# Processing row index : 451
# ------------------------------------------
# Processing row index : 459
# ------------------------------------------
# Processing row index : 461
# ------------------------------------------
# Processing row index : 462
# ------------------------------------------
# Processing row index : 469
# ------------------------------------------
# Processing row index : 470
# ------------------------------------------
# Processing row index : 472
# ------------------------------------------
# Processing row index : 474
# ------------------------------------------
# Processing row index : 475
# ------------------------------------------
# Processing row index : 476
# ------------------------------------------
# Processing row index : 481
# ------------------------------------------
# Processing row index : 482
# ------------------------------------------
# Processing row index : 484
# ------------------------------------------
# Processing row index : 485
# ------------------------------------------
# Processing row index : 488
# ------------------------------------------
# Processing row index : 492
# ------------------------------------------
# Processing row index : 493
# ------------------------------------------
# Processing row index : 495
# ------------------------------------------
# Processing row index : 500
# ------------------------------------------
# Processing row index : 505
# ------------------------------------------
# Processing row index : 506
# ------------------------------------------
# Processing row index : 509
# ------------------------------------------
# Processing row index : 510
# ------------------------------------------
# Processing row index : 514
# ------------------------------------------
# Processing row index : 515
# ------------------------------------------
# Processing row index : 524
# ------------------------------------------
# Processing row index : 539
# ------------------------------------------
# Processing row index : 540
# ------------------------------------------
# Processing row index : 541
# ------------------------------------------
# Processing row index : 545
# ------------------------------------------
# Processing row index : 549
# ------------------------------------------
# Processing row index : 558
# ------------------------------------------
# Processing row index : 560
# ------------------------------------------
# Processing row index : 566
# ------------------------------------------
# Processing row index : 567
# ------------------------------------------
# Processing row index : 568
# ------------------------------------------
# Processing row index : 572
# ------------------------------------------
# Processing row index : 577
# ------------------------------------------
# Processing row index : 579
# ------------------------------------------
# Processing row index : 582
# ------------------------------------------
# Processing row index : 583
# ------------------------------------------
# Processing row index : 585
# ------------------------------------------
# Processing row index : 592
# ------------------------------------------
# Processing row index : 593
# ------------------------------------------
# Processing row index : 596
# ------------------------------------------
# Processing row index : 597
# ------------------------------------------
# Processing row index : 604
# ------------------------------------------
# Processing row index : 607
# ------------------------------------------
# Processing row index : 608
# ------------------------------------------
# Processing row index : 609
# ------------------------------------------
# Processing row index : 610
# ------------------------------------------
# Processing row index : 614
# ------------------------------------------
# Processing row index : 617
# ------------------------------------------
# Processing row index : 618
# ------------------------------------------
# Processing row index : 629
# ------------------------------------------
# Processing row index : 630
# ------------------------------------------
# Processing row index : 631
# ------------------------------------------
# Processing row index : 632
# ------------------------------------------
# Processing row index : 633
# ------------------------------------------
# Processing row index : 634
# ------------------------------------------
# Processing row index : 635
# ------------------------------------------
# Processing row index : 636
# ------------------------------------------
# Processing row index : 637
# ------------------------------------------
# Processing row index : 638
# ------------------------------------------
# Processing row index : 639
# ------------------------------------------
# Processing row index : 640
# ------------------------------------------
# Processing row index : 641
# ------------------------------------------
# Processing row index : 642
# ------------------------------------------
# Processing row index : 643
# ------------------------------------------
# Processing row index : 644
# ------------------------------------------
# Processing row index : 645
# ------------------------------------------
# Processing row index : 646
# ------------------------------------------
# Processing row index : 647
# ------------------------------------------
# Processing row index : 648
# ------------------------------------------
# Processing row index : 649
# ------------------------------------------
# Processing row index : 650
# ------------------------------------------
# Processing row index : 651
# ------------------------------------------
# Processing row index : 652
# ------------------------------------------
# Processing row index : 653
# ------------------------------------------
# Processing row index : 654
# ------------------------------------------
# Processing row index : 655
# ------------------------------------------
# Processing row index : 656
# ------------------------------------------
# Processing row index : 657
# ------------------------------------------
# Processing row index : 658
# ------------------------------------------
# Processing row index : 659
# ------------------------------------------
# Processing row index : 660
# ------------------------------------------
# Processing row index : 661
# ------------------------------------------
# Processing row index : 662
# ------------------------------------------
# Processing row index : 663
# ------------------------------------------
# Processing row index : 664
# ------------------------------------------
# Processing row index : 665
# ------------------------------------------
# Processing row index : 666
# ------------------------------------------
# Processing row index : 667
# ------------------------------------------
# Processing row index : 668
# ------------------------------------------
# Processing row index : 669
# ------------------------------------------
# Processing row index : 670
# ------------------------------------------
# Processing row index : 671
# ------------------------------------------
# Processing row index : 672
# ------------------------------------------
# Processing row index : 673
# ------------------------------------------
# Processing row index : 674
# ------------------------------------------
# Processing row index : 675
# ------------------------------------------
# Processing row index : 676
# ------------------------------------------
# Processing row index : 677
# ------------------------------------------
# Processing row index : 678
# ------------------------------------------
# Processing row index : 679
# ------------------------------------------
# Processing row index : 680
# ------------------------------------------
# Processing row index : 681
# ------------------------------------------
# Processing row index : 682
# ------------------------------------------
# Processing row index : 683
# ------------------------------------------
# Processing row index : 684
# ------------------------------------------
# Processing row index : 685
# ------------------------------------------
# Processing row index : 686
# ------------------------------------------
# Processing row index : 687
# ------------------------------------------
# Processing row index : 689
# ------------------------------------------
# Processing row index : 690
# ------------------------------------------
# Processing row index : 691
# ------------------------------------------
# Processing row index : 692
# ------------------------------------------
# Processing row index : 693
# ------------------------------------------
# Processing row index : 694
# ------------------------------------------
# Processing row index : 696
# ------------------------------------------
# Processing row index : 697
# ------------------------------------------
# Processing row index : 698
# ------------------------------------------
# Processing row index : 699
# ------------------------------------------
# Processing row index : 700
# ------------------------------------------
# Processing row index : 702
# ------------------------------------------
# Processing row index : 705
# ------------------------------------------
# Processing row index : 706
# ------------------------------------------
# Processing row index : 707
# ------------------------------------------
# Processing row index : 708
# ------------------------------------------
# Processing row index : 709
# ------------------------------------------
# Processing row index : 710
# ------------------------------------------
# Processing row index : 712
# ------------------------------------------
# Processing row index : 713
# ------------------------------------------
# Processing row index : 714
# ------------------------------------------
# Processing row index : 715
# ------------------------------------------
# Processing row index : 716
# ------------------------------------------
# Processing row index : 717
# ------------------------------------------
# Processing row index : 719
# ------------------------------------------
# Processing row index : 722
# ------------------------------------------
# Processing row index : 723
# ------------------------------------------
# Processing row index : 724
# ------------------------------------------
# Processing row index : 725
# ------------------------------------------
# Processing row index : 727
# ------------------------------------------
# Processing row index : 728
# ------------------------------------------
# Processing row index : 729
# ------------------------------------------
# Processing row index : 730
# ------------------------------------------
# Processing row index : 732
# ------------------------------------------
# Processing row index : 733
# ------------------------------------------
# Processing row index : 734
# ------------------------------------------
# Processing row index : 735
# ------------------------------------------
# Processing row index : 736
# ------------------------------------------
# Processing row index : 737
# ------------------------------------------
# Processing row index : 738
# ------------------------------------------
# Processing row index : 739
# ------------------------------------------
# Processing row index : 740
# ------------------------------------------
# Processing row index : 741
# ------------------------------------------
# Processing row index : 742
# ------------------------------------------
# Processing row index : 743
# ------------------------------------------
# Processing row index : 745
# ------------------------------------------
# Processing row index : 746
# ------------------------------------------
# Processing row index : 747
# ------------------------------------------
# Processing row index : 748
# ------------------------------------------
# Processing row index : 749
# ------------------------------------------
# Processing row index : 750
# ------------------------------------------
# Processing row index : 752
# ------------------------------------------
# Processing row index : 753
# ------------------------------------------
# Processing row index : 754
# ------------------------------------------
# Processing row index : 755
# ------------------------------------------
# Processing row index : 756
# ------------------------------------------
# Processing row index : 758
# ------------------------------------------
# Processing row index : 759
# ------------------------------------------
# Processing row index : 760
# ------------------------------------------
# Processing row index : 761
# ------------------------------------------
# Processing row index : 762
# ------------------------------------------
# Processing row index : 763
# ------------------------------------------
# Processing row index : 765
# ------------------------------------------
# Processing row index : 766
# ------------------------------------------
# Processing row index : 768
# ------------------------------------------
# Processing row index : 769
# ------------------------------------------
# Processing row index : 770
# ------------------------------------------
# Processing row index : 772
# ------------------------------------------
# Processing row index : 773
# ------------------------------------------
# Processing row index : 774
# ------------------------------------------
# Processing row index : 775
# ------------------------------------------
# Processing row index : 776
# ------------------------------------------
# Processing row index : 777
# ------------------------------------------
# Processing row index : 779
# ------------------------------------------
# Processing row index : 780
# ------------------------------------------
# Processing row index : 781
# ------------------------------------------
# Processing row index : 782
# ------------------------------------------
# Processing row index : 783
# ------------------------------------------
# Processing row index : 785
# ------------------------------------------
# Processing row index : 786
# ------------------------------------------
# Processing row index : 787
# ------------------------------------------
# Processing row index : 788
# ------------------------------------------
# Processing row index : 789
# ------------------------------------------
# Processing row index : 791
# ------------------------------------------
# Processing row index : 792
# ------------------------------------------
# Processing row index : 793
# ------------------------------------------
# Processing row index : 795
# ------------------------------------------
# Processing row index : 796
# ------------------------------------------
# Processing row index : 798
# ------------------------------------------
# Processing row index : 799
# ------------------------------------------
# Processing row index : 800
# ------------------------------------------
# Processing row index : 801
# ------------------------------------------
# Processing row index : 802
# ------------------------------------------
# Processing row index : 804
# ------------------------------------------
# Processing row index : 805
# ------------------------------------------
# Processing row index : 806
# ------------------------------------------
# Processing row index : 807
# ------------------------------------------
# Processing row index : 809
# ------------------------------------------
# Processing row index : 810
# ------------------------------------------
# Processing row index : 811
# ------------------------------------------
# Processing row index : 812
# ------------------------------------------
# Processing row index : 813
# ------------------------------------------
# Processing row index : 814
# ------------------------------------------
# Processing row index : 815
# ------------------------------------------
# Processing row index : 817
# ------------------------------------------
# Processing row index : 818
# ------------------------------------------
# Processing row index : 819
# ------------------------------------------
# Processing row index : 820
# ------------------------------------------
# Processing row index : 821
# ------------------------------------------
# Processing row index : 822
# ------------------------------------------
# Processing row index : 823
# ------------------------------------------
# Processing row index : 826
# ------------------------------------------
# Processing row index : 828
# ------------------------------------------
# Processing row index : 829
# ------------------------------------------
# Processing row index : 831
# ------------------------------------------
# Processing row index : 832
# ------------------------------------------
# Processing row index : 834
# ------------------------------------------
# Processing row index : 837
# ------------------------------------------
# Processing row index : 838
# ------------------------------------------
# Processing row index : 841
# ------------------------------------------
# Processing row index : 842
# ------------------------------------------
# Processing row index : 843
# ------------------------------------------
# Processing row index : 845
# ------------------------------------------
# Processing row index : 847
# ------------------------------------------
# Processing row index : 848
# ------------------------------------------
# Processing row index : 850
# ------------------------------------------
# Processing row index : 851
# ------------------------------------------
# Processing row index : 853
# ------------------------------------------
# Processing row index : 854
# ------------------------------------------
# Processing row index : 856
# ------------------------------------------
# Processing row index : 857
# ------------------------------------------
# Processing row index : 859
# ------------------------------------------
# Processing row index : 861
# ------------------------------------------
# Processing row index : 863
# ------------------------------------------
# Processing row index : 864
# ------------------------------------------
# Processing row index : 868
# ------------------------------------------
# Processing row index : 869
# ------------------------------------------
# Processing row index : 870
# ------------------------------------------
# Processing row index : 871
# ------------------------------------------
# Processing row index : 873
# ------------------------------------------
# Processing row index : 874
# ------------------------------------------
# Processing row index : 876
# ------------------------------------------
# Processing row index : 878
# ------------------------------------------
# Processing row index : 879
# ------------------------------------------
# Processing row index : 880
# ------------------------------------------
# Processing row index : 881
# ------------------------------------------
# Processing row index : 882
# ------------------------------------------
# Processing row index : 884
# ------------------------------------------
# Processing row index : 885
# ------------------------------------------
# Processing row index : 893
# ------------------------------------------
# Processing row index : 896
# ------------------------------------------
# Processing row index : 897
# ------------------------------------------
# Processing row index : 898
# ------------------------------------------
# Processing row index : 903
# ------------------------------------------
# Processing row index : 905
# ------------------------------------------
# Processing row index : 906
# ------------------------------------------
# Processing row index : 908
# ------------------------------------------
# Processing row index : 909
# ------------------------------------------
# Processing row index : 915
# ------------------------------------------
# Processing row index : 917
# ------------------------------------------
# Processing row index : 918
# ------------------------------------------
# Processing row index : 919
# ------------------------------------------
# Processing row index : 920
# ------------------------------------------
# Processing row index : 924
# ------------------------------------------
# Processing row index : 926
# ------------------------------------------
# Processing row index : 929
# ------------------------------------------
# Processing row index : 930
# ------------------------------------------
# Processing row index : 931
# ------------------------------------------
# Processing row index : 932
# ------------------------------------------
# Processing row index : 936
# ------------------------------------------
# Processing row index : 937
# ------------------------------------------
# Processing row index : 938
# ------------------------------------------
# Processing row index : 940
# ------------------------------------------
# Processing row index : 941
# ------------------------------------------
# Processing row index : 944
# ------------------------------------------
# Processing row index : 946
# ------------------------------------------
# Processing row index : 951
# ------------------------------------------
# Processing row index : 953
# ------------------------------------------
# Processing row index : 954
# ------------------------------------------
# Processing row index : 955
# ------------------------------------------
# Processing row index : 956
# ------------------------------------------
# Processing row index : 960
# ------------------------------------------
# Processing row index : 963
# ------------------------------------------
# Processing row index : 964
# ------------------------------------------
# Processing row index : 966
# ------------------------------------------
# Processing row index : 969
# ------------------------------------------
# Processing row index : 970
# ------------------------------------------
# Processing row index : 971
# ------------------------------------------
# Processing row index : 974
# ------------------------------------------
# Processing row index : 975
# ------------------------------------------
# Processing row index : 976
# ------------------------------------------
# Processing row index : 977
# ------------------------------------------
# Processing row index : 979
# ------------------------------------------
# Processing row index : 980
# ------------------------------------------
# Processing row index : 982
# ------------------------------------------
# Processing row index : 983
# ------------------------------------------
# Processing row index : 984
# ------------------------------------------
# Processing row index : 986
# ------------------------------------------
# Processing row index : 987
# ------------------------------------------
# Processing row index : 989
# ------------------------------------------
# Processing row index : 990
# ------------------------------------------
# Processing row index : 993
# ------------------------------------------
# Processing row index : 995
# ------------------------------------------
# Processing row index : 996
# ------------------------------------------
# Processing row index : 998
# ------------------------------------------
# Processing row index : 1004
# ------------------------------------------
# Processing row index : 1005
# ------------------------------------------
# Processing row index : 1006
# ------------------------------------------
# Processing row index : 1007
# ------------------------------------------
# Processing row index : 1009
# ------------------------------------------
# Processing row index : 1010
# ------------------------------------------
# Processing row index : 1012
# ------------------------------------------
# Processing row index : 1014
# ------------------------------------------
# Processing row index : 1017
# ------------------------------------------
# Processing row index : 1018
# ------------------------------------------
# Processing row index : 1020
# ------------------------------------------
# Processing row index : 1021
# ------------------------------------------
# Processing row index : 1022
# ------------------------------------------
# Processing row index : 1023
# ------------------------------------------
# Processing row index : 1025
# ------------------------------------------
# Processing row index : 1028
# ------------------------------------------
# Processing row index : 1036
# ------------------------------------------
# Processing row index : 1037
# ------------------------------------------
# Processing row index : 1040
# ------------------------------------------
# Processing row index : 1041
# ------------------------------------------
# Processing row index : 1042
# ------------------------------------------
# Processing row index : 1044
# ------------------------------------------
# Processing row index : 1045
# ------------------------------------------
# Processing row index : 1046
# ------------------------------------------
# Processing row index : 1047
# ------------------------------------------
# Processing row index : 1048
# ------------------------------------------
# Processing row index : 1049
# ------------------------------------------
# Processing row index : 1050
# ------------------------------------------
# Processing row index : 1052
# ------------------------------------------
# Processing row index : 1053
# ------------------------------------------
# Processing row index : 1058
# ------------------------------------------
# Processing row index : 1059
# ------------------------------------------
# Processing row index : 1060
# ------------------------------------------
# Processing row index : 1062
# ------------------------------------------
# Processing row index : 1063
# ------------------------------------------
# Processing row index : 1066
# ------------------------------------------
# Processing row index : 1069
# ------------------------------------------
# Processing row index : 1070
# ------------------------------------------
# Processing row index : 1071
# ------------------------------------------
# Processing row index : 1072
# ------------------------------------------
# Processing row index : 1073
# ------------------------------------------
# Processing row index : 1076
# ------------------------------------------
# Processing row index : 1078
# ------------------------------------------
# Processing row index : 1081
# ------------------------------------------
# Processing row index : 1083
# ------------------------------------------
# Processing row index : 1087
# ------------------------------------------
# Processing row index : 1090
# ------------------------------------------
# Processing row index : 1091
# ------------------------------------------
# Processing row index : 1092
# ------------------------------------------
# Processing row index : 1096
# ------------------------------------------
# Processing row index : 1101
# ------------------------------------------
# Processing row index : 1109
# ------------------------------------------
# Processing row index : 1116
# ------------------------------------------
# Processing row index : 1120
# ------------------------------------------
# Processing row index : 1121
# ------------------------------------------
# Processing row index : 1122
# ------------------------------------------
# Processing row index : 1126
# ------------------------------------------
# Processing row index : 1129
# ------------------------------------------
# Processing row index : 1130
# ------------------------------------------
# Processing row index : 1132
# ------------------------------------------
# Processing row index : 1133
# ------------------------------------------
# Processing row index : 1135
# ------------------------------------------
# Processing row index : 1136
# ------------------------------------------
# Processing row index : 1140
# ------------------------------------------
# Processing row index : 1142
# ------------------------------------------
# Processing row index : 1144
# ------------------------------------------
# Processing row index : 1145
# ------------------------------------------
# Processing row index : 1157
# ------------------------------------------
# Processing row index : 1159
# ------------------------------------------
# Processing row index : 1160
# ...
# ------------------------------------------
# Processing row index : 10671
# ------------------------------------------
# Processing row index : 10672
# ------------------------------------------
# Processing row index : 10673
# ------------------------------------------
# Processing row index : 10674
# ------------------------------------------
# Processing row index : 10676
# ------------------------------------------
# Processing row index : 10677
# ------------------------------------------
# Processing row index : 10678
# ------------------------------------------
# Processing row index : 10679
# ------------------------------------------
# Processing row index : 10681
# ------------------------------------------
# Processing row index : 10682
# ------------------------------------------
# Processing row index : 10683
# ------------------------------------------
# Processing row index : 10685
# ------------------------------------------
# Processing row index : 10686
# ------------------------------------------
# Processing row index : 10687
# ------------------------------------------
# Processing row index : 10689
# ------------------------------------------
# Processing row index : 10690
# ------------------------------------------
# Processing row index : 10691
# ------------------------------------------
# Processing row index : 10692
# ------------------------------------------
# Processing row index : 10693
# ------------------------------------------
# Processing row index : 10694
# ------------------------------------------
# Processing row index : 10695
# ------------------------------------------
# Processing row index : 10696
# ------------------------------------------
# Processing row index : 10697
# ------------------------------------------
# Processing row index : 10698
# ------------------------------------------
# Processing row index : 10699
# ------------------------------------------
# Processing row index : 10700
# ------------------------------------------
# Processing row index : 10701
# ------------------------------------------
# Processing row index : 10702
# ------------------------------------------
# Processing row index : 10705
# ------------------------------------------
# Processing row index : 10706
# ------------------------------------------
# Processing row index : 10707
# ------------------------------------------
# Processing row index : 10710
# ------------------------------------------
# Processing row index : 10711
# ------------------------------------------
# Processing row index : 10712
# ------------------------------------------
# Processing row index : 10713
# ------------------------------------------
# Processing row index : 10714
# ------------------------------------------
# Processing row index : 10715
# ------------------------------------------
# Processing row index : 10717
# ------------------------------------------
# Processing row index : 10718
# ------------------------------------------
# Processing row index : 10720
# ------------------------------------------
# Processing row index : 10721
# ------------------------------------------
# Processing row index : 10722
# ------------------------------------------
# Processing row index : 10724
# ------------------------------------------
# Processing row index : 10725
# ------------------------------------------
# Processing row index : 10726
# ------------------------------------------
# Processing row index : 10727
# ------------------------------------------
# Processing row index : 10728
# ------------------------------------------
# Processing row index : 10729
# ------------------------------------------
# Processing row index : 10731
# ------------------------------------------
# Processing row index : 10734
# ------------------------------------------
# Processing row index : 10736
# ------------------------------------------
# Processing row index : 10737
# ------------------------------------------
# Processing row index : 10740
# ------------------------------------------
# Processing row index : 10742
# ------------------------------------------
# Processing row index : 10743
# ------------------------------------------
# Processing row index : 10744
# ------------------------------------------
# Processing row index : 10746
# ------------------------------------------
# Processing row index : 10747
# ------------------------------------------
# Processing row index : 10750
# ------------------------------------------
# Processing row index : 10751
# ------------------------------------------
# Processing row index : 10752
# ------------------------------------------
# Processing row index : 10755
# ------------------------------------------
# Processing row index : 10756
# ------------------------------------------
# Processing row index : 10757
# ------------------------------------------
# Processing row index : 10758
# ------------------------------------------
# Processing row index : 10759
# ------------------------------------------
# Processing row index : 10760
# ------------------------------------------
# Processing row index : 10761
# ------------------------------------------
# Processing row index : 10762
# ------------------------------------------
# Processing row index : 10763
# ------------------------------------------
# Processing row index : 10764
# ------------------------------------------
# Processing row index : 10765
# ------------------------------------------
# Processing row index : 10766
# ------------------------------------------
# Processing row index : 10767
# ------------------------------------------
# Processing row index : 10768
# ------------------------------------------
# Processing row index : 10769
# ------------------------------------------
# Processing row index : 10770
# ------------------------------------------
# Processing row index : 10771
# ------------------------------------------
# Processing row index : 10772
# ------------------------------------------
# Processing row index : 10773
# ------------------------------------------
# Processing row index : 10774
# ------------------------------------------
# Processing row index : 10775
# ------------------------------------------
# Processing row index : 10776
# ------------------------------------------
# Processing row index : 10779
# ------------------------------------------
# Processing row index : 10780
# ------------------------------------------
# Processing row index : 10781
# ------------------------------------------
# Processing row index : 10783
# ------------------------------------------
# Processing row index : 10784
# ------------------------------------------
# Processing row index : 10785
# ------------------------------------------
# Processing row index : 10786
# ------------------------------------------
# Processing row index : 10788
# ------------------------------------------
# Processing row index : 10789
# ------------------------------------------
# Processing row index : 10790
# ------------------------------------------
# Processing row index : 10791
# ------------------------------------------
# Processing row index : 10792
# ------------------------------------------
# Processing row index : 10793
# ------------------------------------------
# Processing row index : 10794
# ------------------------------------------
# Processing row index : 10795
# ------------------------------------------
# Processing row index : 10796
# ------------------------------------------
# Processing row index : 10797
# ------------------------------------------
# Processing row index : 10799
# ------------------------------------------
# Processing row index : 10800
# ------------------------------------------
# Processing row index : 10801
# ------------------------------------------
# Processing row index : 10802
# ------------------------------------------
# Processing row index : 10805
# ------------------------------------------
# Processing row index : 10808
# ------------------------------------------
# Processing row index : 10810
# ------------------------------------------
# Processing row index : 10812
# ------------------------------------------
# Processing row index : 10814
# ------------------------------------------
# Processing row index : 10815
# ------------------------------------------
# Processing row index : 10817
# ------------------------------------------
# Processing row index : 10818
# ------------------------------------------
# Processing row index : 10819
# ------------------------------------------
# Processing row index : 10820
# ------------------------------------------
# Processing row index : 10821
# ------------------------------------------
# Processing row index : 10822
# ------------------------------------------
# Processing row index : 10823
# ------------------------------------------
# Processing row index : 10824
# ------------------------------------------
# Processing row index : 10825
# ------------------------------------------
# Processing row index : 10826
# ------------------------------------------
# Processing row index : 10827
# ------------------------------------------
# Processing row index : 10828
# ------------------------------------------
# Processing row index : 10829
# ------------------------------------------
# Processing row index : 10831
# ------------------------------------------
# Processing row index : 10832
# ------------------------------------------
# Processing row index : 10833
# ------------------------------------------
# Processing row index : 10834
# ------------------------------------------
# Processing row index : 10835
# ------------------------------------------
# Processing row index : 10836
# ------------------------------------------
# Processing row index : 10837
# ------------------------------------------
# Processing row index : 10838
# ------------------------------------------
# Processing row index : 10839
# ------------------------------------------
# Processing row index : 10841
# ------------------------------------------
# Processing row index : 10843
# ------------------------------------------
# Processing row index : 10844
# ------------------------------------------
# Processing row index : 10845
# ------------------------------------------
# Processing row index : 10846
# ------------------------------------------
# Processing row index : 10847
# ------------------------------------------
# Processing row index : 10848
# ------------------------------------------
# Processing row index : 10849
# ------------------------------------------
# Processing row index : 10850
# ------------------------------------------
# Processing row index : 10851
# ------------------------------------------
# Processing row index : 10852
# ------------------------------------------
# Processing row index : 10854
# ------------------------------------------
# Processing row index : 10855
# ------------------------------------------
# Processing row index : 10856
# ------------------------------------------
# Processing row index : 10857
# ------------------------------------------
# Processing row index : 10858
# ------------------------------------------
# Processing row index : 10860
# ------------------------------------------
# Processing row index : 10862
# ------------------------------------------
# Processing row index : 10864
# ------------------------------------------
# Processing row index : 10865
# ------------------------------------------
# Processed all rows in dataset
# Generated new dataframe
# Shape of new dataset : (18258, 20)
# ................................................................
#                                                                       0  \
# id                                                               135397
# imdb_id                                                       tt0369610
# popularity                                                    32.985763
# budget                                                        150000000
# revenue                                                      1513528810
# original_title                                           Jurassic World
# cast                  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# director                                                Colin Trevorrow
# tagline                                               The park is open.
# keywords              monster|dna|tyrannosaurus rex|velociraptor|island
# overview              Twenty-two years after the events of Jurassic ...
# runtime                                                             124
# genres                                                           Action
# production_companies  Universal Studios|Amblin Entertainment|Legenda...
# vote_count                                                         5562
# vote_average                                                        6.5
# release_year                                                       2015
# budget_adj                                             137999939.280026
# revenue_adj                                             1392445892.5238
# no_website                                                        False
#
#                                                                       1  \
# id                                                               135397
# imdb_id                                                       tt0369610
# popularity                                                    32.985763
# budget                                                        150000000
# revenue                                                      1513528810
# original_title                                           Jurassic World
# cast                  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# director                                                Colin Trevorrow
# tagline                                               The park is open.
# keywords              monster|dna|tyrannosaurus rex|velociraptor|island
# overview              Twenty-two years after the events of Jurassic ...
# runtime                                                             124
# genres                                                        Adventure
# production_companies  Universal Studios|Amblin Entertainment|Legenda...
# vote_count                                                         5562
# vote_average                                                        6.5
# release_year                                                       2015
# budget_adj                                             137999939.280026
# revenue_adj                                             1392445892.5238
# no_website                                                        False
#
#                                                                       2
# id                                                               135397
# imdb_id                                                       tt0369610
# popularity                                                    32.985763
# budget                                                        150000000
# revenue                                                      1513528810
# original_title                                           Jurassic World
# cast                  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# director                                                Colin Trevorrow
# tagline                                               The park is open.
# keywords              monster|dna|tyrannosaurus rex|velociraptor|island
# overview              Twenty-two years after the events of Jurassic ...
# runtime                                                             124
# genres                                                  Science Fiction
# production_companies  Universal Studios|Amblin Entertainment|Legenda...
# vote_count                                                         5562
# vote_average                                                        6.5
# release_year                                                       2015
# budget_adj                                             137999939.280026
# revenue_adj                                             1392445892.5238
# no_website                                                        False

# %%
# Current shape of dataset
df.shape
# Out:
# (18258, 20)

# %%
# List of movie genres
df["genres"].unique()
# Out:
# array(['Action', 'Adventure', 'Science Fiction', 'Thriller', 'Fantasy',
#        'Crime', 'Western', 'Drama', 'Family', 'Animation', 'Comedy',
#        'Mystery', 'Romance', 'War', 'History', 'Music', 'Horror',
#        'Documentary', 'TV Movie', 'Foreign'], dtype=object)

# %% [markdown]
# ### Between the genres of movies on trend, what is the correlation between them and revenue ?

# %% [markdown]
# ### What is the minimum amount of money to invest in a given genre in order to have the higher revenue possible ?

# %% [markdown]
# ### What is the companies that are best at the genre of movie that is of interest to us ?

# %%
# Continue to explore the data to address your additional research
#   questions. Add more headers as needed if you have more questions to
#   investigate.

# %% [markdown]
# ### Does having a website for the genre that is of interest to us help improve revenue ?

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# > **Tip**: Finally, summarize your findings and the results that have been performed. Make sure that you are clear with regards to the limitations of your exploration. If you haven't done any statistical tests, do not imply any statistical conclusions. And make sure you avoid implying causation from correlation!
#
# > **Tip**: Once you are satisfied with your work, you should save a copy of the report in HTML or PDF form via the **File** > **Download as** submenu. Before exporting your report, check over it to make sure that the flow of the report is complete. You should probably remove all of the "Tip" quotes like this one so that the presentation is as tidy as possible. Congratulations!
